# %%
import pandas as pd 
import seaborn as sns
from matplotlib import pyplot as plt 
import os

# %%
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  'Code',
#  'Datasets',
#  'data_download.py',
#  'Resources',
#  'Untitled Folder',
#  'Untitled.ipynb',
#  'WPR']

# %%
dat = pd.read_csv("./Datasets/COVID-19 Cases(14-03-2022).csv", parse_dates = ["Date"], dayfirst = True, index_col = "S. No.")

# %%
dat = dat[[x.year >= 2020 for x in dat["Date"]]].fillna(0)
dat = dat[dat["Region"] != "World"]
#dat = dat[dat["Region"] != "India"]

# %%
dat["p_death"] = dat["Death"]/(dat["Cured/Discharged"] + dat["Death"] )

# %%
dat = dat.fillna(0)

# %%
dat.to_csv("dat_new.csv")

# %%
#dat[["Date", "Region", "p_death"]].pivot(index = "Date", columns = "Region" , values = "p_death")

# %%
plt.plot(dat[dat["Region"] == "Sikkim"]["p_death"])

# %%
plt.plot(dat[dat["Region"] == "Ladakh"]["p_death"])

# %%
plt.plot(dat[dat["Region"] == "West Bengal"]["p_death"])

# %%
#statewise p_death

# %%
regions = dat.Region.unique()
risk_region = dat.pivot(columns = "Region" , values = "p_death")

# %%
regions
# Out:
# array(['India', 'Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh',
#        'Lakshadweep', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'State assignment pending',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', 'World'], dtype=object)
